# %%
from google.colab.patches import cv2_imshow
import cv2

# %%
img=cv2.imread('lena.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F22ADAF1A90>

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F22AD20FB70>

# %%
inverteted_img=255-gray_img
cv2_imshow(inverteted_img)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F22AD20FAC8>

# %%
blured_img=cv2.GaussianBlur(inverteted_img,(21,21),0)
cv2_imshow(blured_img)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F22AD20FC88>

# %%
inverting_blured_img=255-blured_img
sketch=cv2.divide(gray_img,inverting_blured_img,scale=265.0)
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F22AD20FDD8>

# %%
img=cv2.imread('lena.png')
sketch=cv2.divide(gray_img,inverting_blured_img,scale=265.0)
cv2_imshow(img)
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F22AD21C240>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F22AD21C2E8>
